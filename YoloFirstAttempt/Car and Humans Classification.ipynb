# %%
from google.colab import drive
drive.mount('/content/gdrive')
# This to get access from drive that we will make changes 
# When permission given this is o/p Mounted at /content/gdrive
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/
# Changing our path of current dir

# %%
# !pwd
# Check dir command

# %%
import os
if not os.path.isdir('Firstattempt'):
  os.makedirs("Firstattempt")

# %%
# %cd Firstattempt

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Cloning yolo7 directly from github

# %% [markdown]
# # Downloading pretrained models

# %%
# %cd yolov7/
# since we are downloading pre-trained models kept them in yolov7 folder
# !pwd

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# !pwd

# %%
# !python detect.py --weights yolov7.pt --conf 0.5 --img-size 640 --source RUnway.mp4
